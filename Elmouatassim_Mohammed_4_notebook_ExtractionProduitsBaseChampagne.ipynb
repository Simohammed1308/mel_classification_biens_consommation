# %% [markdown]
# ### Collecte d'aliments à base de CHAMPAGNE par RapidAPI

# %%
import numpy as np
import pandas as pd
import json

# %%
import requests

url = "https://edamam-food-and-grocery-database.p.rapidapi.com/api/food-database/v2/parser"

querystring = {"ingr":"champagne"}

headers = {
    "X-RapidAPI-Key": "a26432c8c6msh816b7607bf1a538p18cb24jsn0b57d2279cdb",
    "X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
response.json()
# Out:
# {'text': 'champagne',
#  'parsed': [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#     'label': 'Champagne',
#     'knownAs': 'dry white wine',
#     'nutrients': {'ENERC_KCAL': 82.0,
#      'PROCNT': 0.07,
#      'FAT': 0.0,
#      'CHOCDF': 2.6,
#      'FIBTG': 0.0},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'}}],
#  'hints': [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#     'label': 'Champagne',
#     'knownAs': 'dry white wine',
#     'nutrients': {'ENERC_KCAL': 82.0,
#      'PROCNT': 0.07,
#      'FAT': 0.0,
#      'CHOCDF': 2.6,
#      'FIBTG': 0.0},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
# ...

# %%
resultat = response.json()
res = resultat['hints']
res
# Out:
# [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#    'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#    'label': 'Champagne',
#    'knownAs': 'dry white wine',
#    'nutrients': {'ENERC_KCAL': 82.0,
#     'PROCNT': 0.07,
#     'FAT': 0.0,
#     'CHOCDF': 2.6,
#     'FIBTG': 0.0},
#    'category': 'Generic foods',
#    'categoryLabel': 'food',
#    'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'},
#   'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#     'label': 'Whole',
#     'weight': 750.0},
#    {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#     'label': 'Serving',
#     'weight': 147.0},
#    {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_splash',
#     'label': 'Splash',
#     'weight': 84.0},
#    {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#     'label': 'Gram',
#     'weight': 1.0},
# ...

# %%
df_res = pd.DataFrame(res)

# %%
df_res
# Out:
#                                                  food  \
# 0   {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu'...
# 1   {'foodId': 'food_b753ithamdb8psbt0w2k9aquo06c'...
# 2   {'foodId': 'food_b3dyababjo54xobm6r8jzbghjgqe'...
# 3   {'foodId': 'food_a9e0ghsamvoc45bwa2ybsa3gken9'...
# 4   {'foodId': 'food_an4jjueaucpus2a3u1ni8auhe7q9'...
# 5   {'foodId': 'food_bmu5dmkazwuvpaa5prh1daa8jxs0'...
# 6   {'foodId': 'food_alpl44taoyv11ra0lic1qa8xculi'...
# 7   {'foodId': 'food_byap67hab6evc3a0f9w1oag3s0qf'...
# 8   {'foodId': 'food_am5egz6aq3fpjlaf8xpkdbc2asis'...
# 9   {'foodId': 'food_bcz8rhiajk1fuva0vkfmeakbouc0'...
# 10  {'foodId': 'food_a79xmnya6togreaeukbroa0thhh0'...
# 11  {'foodId': 'food_aoxaf73b3o0igebpj6wjga6kqhco'...
# 12  {'foodId': 'food_ax1n26waalpd9cbc64bjob7pw6hg'...
# 13  {'foodId': 'food_b4va8u0bb6pf74akh2rtcb3llna9'...
# 14  {'foodId': 'food_a4j8wm8ayflf13b45t3c3bk9w4ek'...
# 15  {'foodId': 'food_bw7gtgxbnn7nbwa62ppwpar9ljc1'...
# ...

# %%
pd.set_option("display.max_colwidth", 600)

# %%
df_res[0:1]['food']
# Out:
# 0    {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu', 'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine', 'label': 'Champagne', 'knownAs': 'dry white wine', 'nutrients': {'ENERC_KCAL': 82.0, 'PROCNT': 0.07, 'FAT': 0.0, 'CHOCDF': 2.6, 'FIBTG': 0.0}, 'category': 'Generic foods', 'categoryLabel': 'food', 'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'}
# Name: food, dtype: object

# %%
df_res[0:1]['measures']
# Out:
# 0    [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit', 'label': 'Whole', 'weight': 750.0}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving', 'label': 'Serving', 'weight': 147.0}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_splash', 'label': 'Splash', 'weight': 84.0}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram', 'label': 'Gram', 'weight': 1.0}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce', 'label': 'Ounce', 'weight': 28.349523125}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_po...
# Name: measures, dtype: object

# %%
df_res['food'].to_json('food.json')

# %%
df_res['measures'].to_json('measures.json')

# %%
df_food = pd.read_json('food.json')
#df_measures = pd.read_json('measures.json')

# %%
df_food_T = df_food.transpose()
#df_measures_T = df_measures.transpose()

# %%
df_food_T.sample(3)
# Out:
#                                foodId  \
# 8   food_am5egz6aq3fpjlaf8xpkdbc2asis
# 17  food_bba727vaimolf0b8stgoibx7ujei
# 2   food_b3dyababjo54xobm6r8jzbghjgqe
#
#                                                                             uri  \
# 8   http://www.edamam.com/ontologies/edamam.owl#_generic_meal_champagne_truffle
# 17     http://www.edamam.com/ontologies/edamam.owl#_generic_meal_cake_champagne
# 2                http://www.edamam.com/ontologies/edamam.owl#Food_FDCBR_1069751
#
#                                label                           knownAs  \
# 8                 Champagne Truffles                Champagne Truffles
# 17                    Champagne Cake                    Champagne Cake
# 2   Champagne Vinaigrette, Champagne  CHAMPAGNE VINAIGRETTE, CHAMPAGNE
#
#                                                                                                                        nutrients  \
# ...

# %%
df_food_T.label.value_counts()
# Out:
# Champagne Vinaigrette, Champagne                   4
# Champagne                                          1
# Champagne Jelly                                    1
# Champagne Cupcakes                                 1
# Champagne Cake                                     1
# Champagne Simply Dressed Vinaigrette, Champagne    1
# Champagne Cotton Candy, Champagne                  1
# Champagne Sangria                                  1
# Champagne Punch                                    1
# Strawberry Champagne                               1
# Champagne Chicken                                  1
# Champagne Vinaigrette                              1
# Champagne Truffles                                 1
# Champagne Sorbet                                   1
# Champagne Buttercream                              1
# Champagne Dressing, Champagne                      1
# Champagne Vinegar                                  1
# Name: label, dtype: int64

# %%
df_food_T.shape
# Out:
# (20, 12)

# %%
df_food_T.columns
# Out:
# Index(['foodId', 'uri', 'label', 'knownAs', 'nutrients', 'category',
#        'categoryLabel', 'image', 'brand', 'foodContentsLabel', 'servingSizes',
#        'servingsPerContainer'],
#       dtype='object')

# %% [markdown]
# - on ne garde que les champs suivants : foodId, label, category, foodContentsLabel, image.

# %%
df_final = df_food_T[['foodId','label','category','foodContentsLabel','image']].copy()

# %%
df_final.sample(5)
# Out:
#                                foodId  \
# 11  food_aoxaf73b3o0igebpj6wjga6kqhco
# 16  food_bu12urpbtuo9v6b4jpvk2a1fh4hh
# 6   food_alpl44taoyv11ra0lic1qa8xculi
# 2   food_b3dyababjo54xobm6r8jzbghjgqe
# 0   food_a656mk2a5dmqb2adiamu6beihduu
#
#                                               label        category  \
# 11                             Strawberry Champagne   Generic meals
# 16  Champagne Simply Dressed Vinaigrette, Champagne  Packaged foods
# 6                             Champagne Buttercream   Generic meals
# 2                  Champagne Vinaigrette, Champagne  Packaged foods
# 0                                         Champagne   Generic foods
#
#                                                                                                                                                       foodContentsLabel  \
# ...

# %%
df_final.columns
# Out:
# Index(['foodId', 'label', 'category', 'foodContentsLabel', 'image'], dtype='object')

# %%
# 10 premiers produits
df_final[0:10]
# Out:
#                               foodId                             label  \
# 0  food_a656mk2a5dmqb2adiamu6beihduu                         Champagne
# 1  food_b753ithamdb8psbt0w2k9aquo06c  Champagne Vinaigrette, Champagne
# 2  food_b3dyababjo54xobm6r8jzbghjgqe  Champagne Vinaigrette, Champagne
# 3  food_a9e0ghsamvoc45bwa2ybsa3gken9  Champagne Vinaigrette, Champagne
# 4  food_an4jjueaucpus2a3u1ni8auhe7q9  Champagne Vinaigrette, Champagne
# 5  food_bmu5dmkazwuvpaa5prh1daa8jxs0     Champagne Dressing, Champagne
# 6  food_alpl44taoyv11ra0lic1qa8xculi             Champagne Buttercream
# 7  food_byap67hab6evc3a0f9w1oag3s0qf                  Champagne Sorbet
# 8  food_am5egz6aq3fpjlaf8xpkdbc2asis                Champagne Truffles
# 9  food_bcz8rhiajk1fuva0vkfmeakbouc0             Champagne Vinaigrette
#
#          category  \
# 0   Generic foods
# 1  Packaged foods
# 2  Packaged foods
# 3  Packaged foods
# 4  Packaged foods
# 5  Packaged foods
# 6   Generic meals
# 7   Generic meals
# ...

# %%
#Sauvegarde dans un fichier csv du 10 premiers produits
df_final[0:10].to_csv('./data/csv/champagne.csv')

# %% [markdown]
# ### Fin
